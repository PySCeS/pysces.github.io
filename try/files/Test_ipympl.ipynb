# %% [markdown]
# # Test_ipympl

# %% [markdown]
# This demonstrates the use of the `ipympl` matplotlib plotting widget in JupyterLab.

# %%
# %pip install ipympl
# %matplotlib widget

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# Use the icons on the left to resize, zoom, drag or otherwise change the plot. Clicking `home` returns to the original view.

# %%
plt.plot([1,3,2])
